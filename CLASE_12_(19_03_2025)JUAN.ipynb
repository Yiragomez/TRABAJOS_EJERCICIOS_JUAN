# %% [markdown]
# <a href="https://colab.research.google.com/github/Yiragomez/TRABAJOS_EJERCICIOS_JUAN/blob/main/CLASE_12_(19_03_2025)JUAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Agregar clientes
def agregar_cliente(lista_clientes, nombre):
    if isinstance(nombre, str)and 2 <= len(nombre) <= 50:
        lista_clientes.append(nombre.title())
        print(f"cliente agregado: {nombre.title()}")
    else:
      print("Nombre de cliente invalido debe tener entre 2 a 50 caracteres")
#Recorrer la lista y mosstrar los clientes con For
def mostrar_clientes(lista_clientes):
    for cliente in lista_clientes:
        print(f"-> {cliente}")
#Modificar un nombre en caso de error
def modificar_cliente(lista_clientes, indice, nuevo_nombre):
    if not isinstance(nuevo_nombre, str) and 2 <= len(nuevo_nombre) <= 50:
        print("Nombre de cliente invalido debe tener entre 2 a 50 caracteres")
        return #termina la funcion
    if 0 <= indice < len(lista_clientes):
        nombre_original = lista_clientes[indice]
        lista_clientes[indice]= nuevo_nombre.title()
        print(f"El cliente {nombre_original} fue reemplazado por: {nuevo_nombre.title()} ")
    else:
      print("No se encontro el dato, numero de la lista erroneo")
  #Borrar un cliente
def borrar_cliente(lista_clientes, indice):
      if 0 <- indice < len(lista_clientes):
          borrar = lista_clientes.pop[indice]
          print(f"El cliente {borrar}, se borro de la lista clientes.")
      else:
        print("No se encontro el cliente, cliente borrado de la lista. ")
def main():

  #simulacion empresarial
    clientes= ["Hugo", "Paco", "Luis", "TioGranpa"]
    print("Clientes actuales")
    mostrar_clientes(clientes)
    #1. Agregar nuevos clientesd append()
    agregar_cliente(clientes, "alexander")
    mostrar_clientes(clientes)
    #3 Modificar un nombre en caso de error
    modificar_cliente(clientes, 1, "Diego")
    mostrar_clientes(clientes)
    #4.Borrar un cliente
    borrar_cliente(clientes, 3)

if __name__ == "__main__":
    main()
# Out:
# Clientes actuales
# -> Hugo
# -> Paco
# -> Luis
# -> TioGranpa
# cliente agregado: Alexander
# -> Hugo
# -> Paco
# -> Luis
# -> TioGranpa
# -> Alexander
# El cliente Paco fue reemplazado por: Diego
# -> Hugo
# -> Diego
# -> Luis
# -> TioGranpa
# -> Alexander
# No se encontro el cliente, cliente borrado de la lista.

# %%
#Agregar muebles
def agregar_mueble(lista_muebles, elemento):
    if isinstance(elemento, str)and 2 <= len(elemento) <= 50:
        lista_muebles.append(elemento.title())
        print(f"mueble agregado: {elemento}")
    else:
      print("Nombre de mueble invalido debe tener entre 2 a 50 caracteres")
#Recorrer la lista y mosstrar los muebles con For
def mostrar_muebles(lista_muebles):
    for mueble in lista_muebles:
        print(f"-> {mueble}")
#Modificar un nombre en caso de error
def modificar_mueble(lista_muebles, indice, nuevo_elemento):
    if not isinstance(nuevo_elemento, str) and 2 <= len(nuevo_elemento) <= 50:
        print("Nombre de mueble invalido debe tener entre 2 a 50 caracteres")
        return #termina la funcion
    if 0 <= indice < len(lista_muebles):
        nombre_original = lista_muebles[indice]
        lista_muebles[indice]= nuevo_elemento.title()
        print(f"El mueble {nuevo_elemento} fue reemplazado por: {nuevo_elemento} ")
    else:
      print("No se encontro el dato, numero de la lista erroneo")
  #Borrar un mueble
def borrar_mueble(lista_muebles, indice):
      if 0 <- indice < len(lista_muebles):
          borrar = lista_muebles.pop[indice]
          print(f"El mueble {borrar}, se borro de la lista clientes.")
      else:
        print("No se encontro el mueble, mueble borrado de la lista. ")
def main():

  #simulacion empresarial
    muebles= ["tablero", "meson", "cajon", "computador"]
    print("muebles actuales")
    mostrar_muebles(muebles)
    #1. Agregar nuevos muebles append()
    agregar_mueble(muebles, "tablets")
    mostrar_muebles(muebles)
    #3 Modificar un nombre en caso de error
    modificar_mueble(muebles, 1, "silla")
    mostrar_muebles(muebles)
    #4.Borrar un mueble
    borrar_mueble(muebles, 3)

if __name__ == "__main__":
    main()
# Out:
# muebles actuales
# -> tablero
# -> meson
# -> cajon
# -> computador
# mueble agregado: tablets
# -> tablero
# -> meson
# -> cajon
# -> computador
# -> Tablets
# El mueble silla fue reemplazado por: silla
# -> tablero
# -> Silla
# -> cajon
# -> computador
# -> Tablets
# No se encontro el mueble, mueble borrado de la lista.

# %%
def mostrar_inventario(productos):
  print("\nMostrar inventario actual")
  if not productos:
      print("No hay produjctos registrados")
      return
  for i, producto in enumerate(productos, start=1):
      print(f"{i}. {producto['nombre']} -{producto['cantidad']:.2f}")
def agregar_productos(productos, nombre, precio):
    if isinstance(nombre, str) and nombre.strip() and isinstance(precio, (int, float)) and precio >0:
         productos.append({"nombre": nombre.title(), "precio": precio})
    else:
      print("Datos invalidos, el nombre debe ser texto y no vacio y el precio numero positivo")

def main():
    inventario = [
        {"nombre": "Camisa", "precio": 29.99},
        {"nombre": "Pantalón", "precio": 39.99},
        {"nombre": "Zapatos", "precio": 59.99}


    ]
if _name__ == "__main__":
    #inventario inicial
